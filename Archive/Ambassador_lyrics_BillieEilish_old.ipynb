# %%
artist = "Billie Eilish"
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
import codecs
import json
from pandas.io.json import json_normalize
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Machine learning libraries for Text analysis
import nltk  # machine learning with text
from nltk import download as nltk_download
from nltk.corpus import stopwords, wordnet  # List of common words
from nltk.tokenize import word_tokenize  # Split text into significant forms
from nltk.stem import WordNetLemmatizer  # Reduce words to their root form
from nltk import pos_tag  # Tag words with parts of speech
from collections import defaultdict  # Dictionaries that have a backup value
from sklearn.feature_extraction.text import CountVectorizer  # Convert text to sparse matrices
from textblob import TextBlob  # Sentiment analysis
from gensim.models.ldamodel import LdaModel  # Topic extraction
from gensim.models.phrases import Phrases  # ngrams
from gensim import corpora  # Vectorization
import pyLDAvis
from wordcloud import WordCloud  # Create wordclouds
import matplotlib.pylab as plt
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from lyricsgenius import Genius

genius = Genius('JOSfSO0Cn0Y3avlw_ItRLdmwFj3s-36fjS-POUolMGFiWkUiE_zHXfQZVsOOqbxA')
artist = genius.search_artist(artist, max_songs=200)
artist_json = artist.save_lyrics()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Searching for songs by Billie Eilish...
#
# Song 1: "​when the party’s over"
# Song 2: "​everything i wanted"
# Song 3: "​bad guy"
# Song 4: "​idontwannabeyouanymore"
# Song 5: "​bury a friend"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-201-70ad704dc442> in <module>
#       2
#       3 genius = Genius('JOSfSO0Cn0Y3avlw_ItRLdmwFj3s-36fjS-POUolMGFiWkUiE_zHXfQZVsOOqbxA')
# ----> 4 artist = genius.search_artist(artist, max_songs=10)
#       5 billie_json = artist.save_lyrics()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/lyricsgenius/genius.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id, include_features)
#     562                 # Create the Song object from lyrics and metadata
#     563                 if song_info['lyrics_state'] == 'complete':
# --> 564                     lyrics = self.lyrics(song_url=song_info['url'])
#     565                 else:
#     566                     lyrics = ""
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/lyricsgenius/genius.py in lyrics(self, song_id, song_url, remove_section_headers)
#     130         # Scrape the song lyrics from the HTML
#     131         html = BeautifulSoup(
# --> 132             self._make_request(path, web=True).replace('<br/>', '\n'),
#     133             "html.parser"
#     134         )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/lyricsgenius/api/base.py in _make_request(self, path, method, params_, public_api, web, **kwargs)
#      89
#      90             # Enforce rate limiting
# ---> 91             time.sleep(self.sleep_time)
#      92
#      93         if web:
#
# KeyboardInterrupt:

# %%
#artist = pd.read_json('Lyrics_artist.json', orient='index')
#artist = pd.read_json(codecs.open('Lyrics_artist.json','r','utf-8'))
#df = json.loads('Lyrics_artist.json').text
#df = pd.DataFrame.from_dict('Lyrics_artist.json', orient='index')
with open('Lyrics_artist.json') as json_data:
    data = json.load(json_data)

df = pd.DataFrame(data['songs'])
artist_df = df[['full_title', 'artist', 'lyrics']]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# "[Verse 1]\nDon't you know I'm no good for you?\nI've learned to lose you, can't afford to\nTore my shirt to stop you bleedin'\nBut nothin' ever stops you leavin'\n\n[Chorus]\nQuiet when I'm coming home and I'm on my own\nI could lie, say I like it like that, like it like that\nI could lie, say I like it like that, like it like that\n\n[Verse 2]\nDon't you know too much already?\nI'll only hurt you if you let me\nCall me friend, but keep me closer (Call me back)\nAnd I'll call you when the party's over\n\n[Chorus]\nQuiet when I'm coming home and I'm on my own\nAnd I could lie, say I like it like that, like it like that\nYeah, I could lie, say I like it like that, like it like that\n\n[Bridge]\nBut nothin' is better sometimes\nOnce we've both said our goodbyes\nLet's just let it go\nLet me let you go\n[Chorus]\nQuiet when I'm coming home and I'm on my own\nI could lie, say I like it like that, like it like that\nI could lie, say I like it like that, like it like that"

# %%
artist_df.lyrics[1]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#
regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics = artist_df.lyrics.replace(to_replace="won’t", value="will not", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="can’t", value="can not", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="wanna", value="want to", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="n't", value=" not", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics = artist_df.lyrics.replace(to_replace="it's", value="it is", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="i've", value="i have", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="i'm", value="i am", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="n' ", value="ng ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# remove "[verse ..]" and "[chorus]"
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"[A|a]ah|[A|a]agh|[A|a]yy|[O|o]oh", value="", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"[H|h]mm|[M|m]mm|[B|b]rr", value="", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"\[[^]]*\]", value="", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics[2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# "\nwhite shirt now red, my bloody nose\nsleepin', you're on your tippy toes\ncreeping around like no one knows\nthink you're so criminal\nbruises on both my knees for you\ndo not say thank you or please\ni do what i want when i am wanting to\nmy soul? so cynical\n\n\nso you're a tough guy\nlike it really rough guy\njust ca not get enough guy\nchest always so puffed guy\ni am that bad type\nmake your mama sad type\nmake your girlfriend mad tight\nmight seduce your dad type\ni am the bad guy\nduh\n\n\ni am the bad guy\n\n\ni like it when you take control\neven if you know that you do not\nown me, i'll let you play the role\ni'll be your animal\nmy mommy likes to sing along with me\nbut she wo not sing this song\nif she reads all the lyrics\nshe'll pity the men i know\n\nso you're a tough guy\nlike it really rough guy\njust ca not get enough guy\nchest always so puffed guy\ni am that bad type\nmake your mama sad type\nmake your girlfriend mad tight\nmight seduce your dad type\ni am the bad guy\nduh\n\n\ni am the bad guy, duh\ni am only good at being bad, bad\n\n\ni like when you get mad\ni guess i am pretty glad that you're alone\nyou said she's scared of me?\ni mean, i do not see what she sees\nbut maybe it is 'cause i am wearing your cologne\n\n\ni am a bad guy\ni am, i am a bad guy\nbad guy, bad guy\ni am a bad"

# %%
artist_df.lyrics = artist_df.lyrics.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=" ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"\W", value=" ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Remove common words from English lyrics 

artist_df.lyrics = artist_df.lyrics.apply(word_tokenize)
stop_words = stopwords.words("english")
artist_df.lyrics = artist_df.lyrics.apply(lambda x: [y for y in x if y not in stop_words
                                                              and len(y) > 2])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics[2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'white shirt red bloody nose sleepin tippy toe creep around like one know think criminal bruise knee say thank please want want soul cynical tough guy like really rough guy get enough guy chest always puffed guy bad type make mama sad type make girlfriend mad tight might seduce dad type bad guy duh bad guy like take control even know let play role animal mommy like sing along sing song read lyric pity men know tough guy like really rough guy get enough guy chest always puffed guy bad type make mama sad type make girlfriend mad tight might seduce dad type bad guy duh bad guy duh good bad bad like get mad guess pretty glad alone say scar mean see see maybe cause wear cologne bad guy bad guy bad guy bad guy bad'

# %%
lemma = WordNetLemmatizer()

# Dictionary to convert between part-of-speech tags and the ones the lemmatizer understands

tag_dict = defaultdict(lambda : wordnet.NOUN)
tag_dict['J'] = wordnet.ADJ
tag_dict['V'] = wordnet.VERB
tag_dict['R'] = wordnet.ADV

# function to lemmatize a sentence

def get_lemma(word):
    """Gets the POS tag for a word, and then returns the lemmatized form of the word"""
    tag = pos_tag([word])[0][1][0]
    tag = tag_dict[tag]
    
    return lemma.lemmatize(word, tag)

# Perform the lemmatization
artist_df.lyrics = artist_df.lyrics.apply(lambda x: [get_lemma(word) for word in x])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create the list of words and their frequency (corpus)
from gensim import corpora
pyLDAvis.enable_notebook()
dictionary = corpora.Dictionary(artist_df.lyrics )
corpus = [dictionary.doc2bow(text) for text in artist_df.lyrics ]

import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import gensim
NUM_TOPICS = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model3.gensim')
topics = ldamodel.print_topics(num_words=6)
for topic in topics:
    print(topic)
# Out:
# (0, '0.055*"want" + 0.053*"like" + 0.041*"say" + 0.019*"would" + 0.018*"could" + 0.018*"lie"')
# (1, '0.039*"think" + 0.033*"guy" + 0.027*"bad" + 0.021*"know" + 0.021*"friend" + 0.021*"want"')
# (2, '0.031*"eye" + 0.031*"ocean" + 0.029*"never" + 0.020*"make" + 0.018*"wish" + 0.018*"fall"')
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_
 1.7186173297711143, 1.7186144697589205, 1.7186015155860426, 1.718571064867979, 1.7185537365588046, 1.7185439788701433, 1.7185041069354414, 1.7184278960222767, 1.7184278960222767, 4.670117276004114, 7.6157676561207, 7.616800625230702, 5.401316068803932, 2.456231971101721, 3.1950844930042166, 6.143669582103682, 4.662958497246978, 7.6047165690037914, 5.399137075984266, 2.4556611463150375, 2.4550647496546207, 2.4536650260397646, 3.187789443077846, 1.721889183720841, 10.305630055272944, 5.9959765690506, 4.558123480709958, 3.835841102258138, 3.835288071631648, 3.1173240846733923, 3.116937086679186, 10.31876329820871, 2.3989587493168387, 2.398922178932219, 2.3983669880298444 ...

# %% [markdown]
# # Wordcloud

# %%
artist_df.lyrics = artist_df.lyrics.apply(lambda x: " ".join(x))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
artist_df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                  full_title         artist  \
# 0   ​when the party's over by Billie Eilish  Billie Eilish
# 1     ​everything i wanted by Billie Eilish  Billie Eilish
# 2                 ​bad guy by Billie Eilish  Billie Eilish
# 3  ​idontwannabeyouanymore by Billie Eilish  Billie Eilish
# 4           ​bury a friend by Billie Eilish  Billie Eilish
#
#                                               lyrics
# 0  know good learn lose afford tore shirt stop bl...
# 1  dream get everything want think honest might n...
# 2  white shirt red bloody nose sleepin tippy toe ...
# 3  way fall apart twice day wish could feel say s...
# 4  billie want run wonder know scar care fall asl...

# %%
# Create an object that converts strings into a sparse matrix
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features= 20000 , min_df=0.01, ngram_range= (1,1))

# Convert the text column to a sparse matrix

data_dtm = vectorizer.fit_transform(artist_df.lyrics)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create a dataframe of terms and frequencies
# Get the frequency of each term

term_frequencies = data_dtm.sum(axis=0)

# Match frequencies to terms

frequent_terms = [(word, term_frequencies[0, id]) for word, id in vectorizer.vocabulary_.items()]

# Convert the word-frequency pairings to a dataframe

term_df = pd.DataFrame(columns=["term","frequency"], data=frequent_terms)

# Sort the dataframe

term_df.sort_values(by="frequency", ascending=False, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create a dictionary of most frequent terms ((required for word clouds)

term_dict = term_df.set_index('term')['frequency'].to_dict()

# Create a wordcloud of most frequent terms

wc = WordCloud(width=800, height=300, background_color="white",
               max_words=100)

wc.generate_from_frequencies(term_dict)

# Display the cloud

plt.figure(figsize=(20, 10))
plt.title("Word cloud for lyrics including all genres", fontsize = 40, pad = 50 )
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Sentiment

# %%
# Assign sentiment to each lyric
artist_df["sentiment"] = artist_df.lyrics.apply(lambda x: TextBlob(x).sentiment.polarity)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-196-c7165aaaafe9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billie_df["sentiment"] = billie_df.lyrics.apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
artist_df.sort_values(by="sentiment", ascending=False).head(10)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                  full_title         artist  \
# 1     ​everything i wanted by Billie Eilish  Billie Eilish
# 6       ​wish you were gay by Billie Eilish  Billie Eilish
# 5              ​i love you by Billie Eilish  Billie Eilish
# 8             ​​ocean eyes by Billie Eilish  Billie Eilish
# 9           Therefore I Am by Billie Eilish  Billie Eilish
# 3  ​idontwannabeyouanymore by Billie Eilish  Billie Eilish
# 0   ​when the party's over by Billie Eilish  Billie Eilish
# 4           ​bury a friend by Billie Eilish  Billie Eilish
# 7           No Time To Die by Billie Eilish  Billie Eilish
# 2                 ​bad guy by Billie Eilish  Billie Eilish
#
#                                               lyrics  sentiment
# 1  dream get everything want think honest might n...   0.272403
# 6  baby feel good six word never understood never...   0.246667
# 5  true tell lie cry like ooh hell never type let...   0.235629
# 8  watch time stop star ocean eye burning city na...   0.227143
# 9  friend anything damn think man think therefore...   0.174561
# 3  way fall apart twice day wish could feel say s...   0.154286
# 0  know good learn lose afford tore shirt stop bl...   0.150000
# 4  billie want run wonder know scar care fall asl...   0.064286
# 7  know leave alone go show blood bleed blood owe...   0.064286
# 2  white shirt red bloody nose sleepin tippy toe ...  -0.368061
