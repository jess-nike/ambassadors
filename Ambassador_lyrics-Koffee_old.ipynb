# %%
import pandas as pd
import codecs
import json
from pandas.io.json import json_normalize
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Machine learning libraries for Text analysis
import nltk  # machine learning with text
from nltk import download as nltk_download
from nltk.corpus import stopwords, wordnet  # List of common words
from nltk.tokenize import word_tokenize  # Split text into significant forms
from nltk.stem import WordNetLemmatizer  # Reduce words to their root form
from nltk import pos_tag  # Tag words with parts of speech
from collections import defaultdict  # Dictionaries that have a backup value
from sklearn.feature_extraction.text import CountVectorizer  # Convert text to sparse matrices
from textblob import TextBlob  # Sentiment analysis
from gensim.models.ldamodel import LdaModel  # Topic extraction
from gensim.models.phrases import Phrases  # ngrams
from gensim import corpora  # Vectorization
import pyLDAvis
from wordcloud import WordCloud  # Create wordclouds
import matplotlib.pylab as plt
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from lyricsgenius import Genius

genius = Genius('JOSfSO0Cn0Y3avlw_ItRLdmwFj3s-36fjS-POUolMGFiWkUiE_zHXfQZVsOOqbxA')
artist = genius.search_artist("Koffee", max_songs=200)
koffee_json = artist.save_lyrics()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Searching for songs by Koffee...
#
# Song 1: "Toast"
# Song 2: "W"
# Song 3: "Rapture"
# Song 4: "Lockdown"
# Song 5: "Raggamuffin"
# Song 6: "Burning"
# Song 7: "Rapture (Remix)"
# Song 8: "Throne"
# Song 9: "Blazin"
# Song 10: "Pressure"
#
# Reached user-specified song limit (10).
# Done. Found 10 songs.
# Lyrics_Koffee.json already exists. Overwrite?
# (y/n): y
# Wrote Lyrics_Koffee.json.

# %%
#koffee = pd.read_json('Lyrics_koffeeEilish.json', orient='index')
#koffee = pd.read_json(codecs.open('Lyrics_koffeeEilish.json','r','utf-8'))
#df = json.loads('Lyrics_koffeeEilish.json').text
#df = pd.DataFrame.from_dict('Lyrics_koffeeEilish.json', orient='index')
with open('Lyrics_Koffee.json') as json_data:
    data = json.load(json_data)

df = pd.DataFrame(data['songs'])
koffee_df = df[['full_title', 'artist', 'lyrics']]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
koffee_df.lyrics[1]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '[Intro]\n(Yo Izy, are you kidding me?)\n\n[Refrain: Koffee]\nA no news, me ina me prime, a no crime\nWhere\u2005di\u2005dolla sign? Money\u2005pon me mind (Yeah)\nSo me nah\u2005no time fi spend\nTime fi spend\nA me style put me pon di map, me deh pon di top\nAnd me name Koffee-Swag-A-Lot\nDem a chat, me nah no time fi dem\nTime fi dem\n\n[Verse 1: Koffee]\nYeah a so me wake up, yeah\nMoney maker, no makeup (Yeah)\nMe go straight fi di paper (Yeah)\nTell ya, "Wait, see ya later"\nMe step out, everybody look like, "What?"\nMe so fresh, dem say "How you look like dat?"\nHot up every cranny, every nook (Yeah)\nAnd me slick, have every trick ina di book (Yeah)\n\n[Chorus: Koffee]\nEverything we do, we give thanks, tell dem wah we do\nLowe di L, take di W (Ayy, ayy)\nOne thing deh out deh fi you (Ayy, ayy)\nAnd it nah come if you no go\nEverything we do, we give thanks, tell dem wah we do\nLowe di L, take di W (Ayy, ayy)\nOne thing deh out deh fi you (Ayy, ayy)\nAnd it nah come if you no go\n[Refrain: Koffee]\nA no news, me ina me prime, a no crime\nWhere di dolla sign? Money pon me mind (Yeah)\nSo me nah no time fi spend\nTime fi spend\nA me style put me pon di map, me deh pon di top\nAnd me name Koffee-Swag-A-Lot\nDem a chat, me nah no time fi dem\nTime fi dem\n\n[Verse 2: Gunna]\nEverything exotic, all plush\nLil\' baby got a body that I swear I wan\' touch\nPull it out, let her ride it, girl, you know I want lust\nI got her excited, I won\'t stop, I\'m in a rush\nI *** that like lunch, we keep it on hush\nBought you a Benz truck, I love to see you blush\nYou shoppin\' when you land, see you bought a Prada clutch\nWe got a lot of bucks, cash longer than a bus\nHuh, we some warriors (Warriors)\nLookin\' at your heart through the Cartier (Cartier)\nPeons at the top at the Aria (Aria)\n**** she got it locked, Rastafari, yeah (\'Fari, yeah)\nMe, my wa gwan at the party, yeah (Party, yeah)\nWe don\'t fear nothin\', we the hardest, yeah (Hardest, yeah)\nSpendin\' cash for fun get us all a pair (All a pair)\nShe want Gunna-Wunna \'cause the real is rare (Real is rare)\n[Refrain: Koffee]\nA no news, me ina me prime, a no crime\nWhere di dolla sign? Money pon me mind (Yeah)\nSo me nah no time fi spend\nTime fi spend\nA me style put me pon di map, me deh pon di top\nAnd me name Koffee-Swag-A-Lot\nDem a chat, me nah no time fi dem\nTime fi dem\n\n[Verse 3: Koffee]\nPull up in rocket, me blast off\nYou could never get me half off\nYou gon get da full price (Yeah)\nBeen this real my whole life\nMe no err twice, all year flights\nMoncler, \'cause the weather here ice cold\nAnd me really never check the price\nI\'m livin\' my best life \'cause life good\n\n[Chorus: Koffee]\nEverything we do, we give thanks, tell dem wah we do\nLowe di L, take di W (Ayy, ayy)\nOne thing deh out deh fi you (Ayy, ayy)\nAnd it nah come if you no go\nEverything we do, we give thanks, tell dem wah we do\nLowe di L, take di W (Ayy, ayy)\nOne thing deh out deh fi you (Ayy, ayy)\nAnd it nah come if you no go\n[Refrain: Koffee]\nA no news, me ina me prime, a no crime\nWhere di dolla sign? Money pon me mind (Yeah)\nSo me nah no time fi spend\nTime fi spend\nA me style put me pon di map, me deh pon di top\nAnd me name Koffee-Swag-A-Lot\nDem a chat, me nah no time fi dem\nTime fi dem'

# %% [markdown]
# # Lyric Analysis
#
# ## Cleaning the lyrics

# %%
koffee_df.dtypes
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# full_title    object
# artist        object
# lyrics        object
# dtype: object

# %%
koffee_df.lyrics = koffee_df.lyrics.str.lower()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Remove quotes
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="(\u2019)", value="'", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="won’t", value="will not", regex=True)
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="can’t", value="can not", regex=True)
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="wanna", value="want to", regex=True)
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="n't", value=" not", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="it's", value="it is", regex=True)
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="i've", value="i have", regex=True)
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="i'm", value="i am", regex=True)
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace="n' ", value="ng ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# remove "[verse ..]" and "[chorus]"
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace=r"\[[^]]*\]", value="", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=" ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
koffee_df.lyrics = koffee_df.lyrics.replace(to_replace=r"\W", value=" ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Remove common words from English lyrics 

koffee_df.lyrics = koffee_df.lyrics.apply(word_tokenize)
stop_words = stopwords.words("english")
koffee_df.lyrics = koffee_df.lyrics.apply(lambda x: [y for y in x if y not in stop_words
                                                              and len(y) > 2])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
koffee_df.lyrics[1]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['izy',
#  'kidding',
#  'news',
#  'ina',
#  'prime',
#  'crime',
#  'dolla',
#  'sign',
#  'money',
#  'pon',
#  'mind',
#  'yeah',
#  'nah',
#  'time',
#  'spend',
#  'time',
#  'spend',
#  'style',
#  'put',
#  'pon',
#  'map',
#  'deh',
#  'pon',
#  'top',
#  'name',
#  'koffee',
#  'swag',
#  'lot',
#  'dem',
#  'chat',
#  'nah',
#  'time',
#  'dem',
#  'time',
#  'dem',
#  'yeah',
#  'wake',
#  'yeah',
#  'money',
#  'maker',
#  'makeup',
#  'yeah',
#  'straight',
#  'paper',
#  'yeah',
#  'tell',
#  'wait',
#  'see',
#  'later',
#  'step',
#  'everybody',
#  'look',
#  'like',
#  'fresh',
#  'dem',
#  'say',
#  'look',
#  'like',
#  'dat',
#  'hot',
#  'every',
#  'cranny',
#  'every',
#  'nook',
#  'yeah',
#  'slick',
#  'every',
#  'trick',
#  'ina',
#  'book',
#  'yeah',
#  'everything',
#  'give',
#  'thanks',
#  'tell',
#  'dem',
#  'wah',
#  'lowe',
#  'take',
#  'ayy',
#  'ayy',
#  'one',
#  'thing',
#  'deh',
#  'deh',
#  'ayy',
#  'ayy',
#  'nah',
#  'come',
#  'everything',
#  'give',
#  'thanks',
#  'tell',
#  'dem',
#  'wah',
#  'lowe',
#  'take',
#  'ayy',
#  'ayy',
#  'one',
#  'thing',
#  'deh',
#  'deh',
#  'ayy',
#  'ayy',
#  'nah',
#  'come',
#  'news',
#  'ina',
#  'prime',
#  'crime',
#  'dolla',
#  'sign',
#  'money',
#  'pon',
#  'mind',
#  'yeah',
#  'nah',
#  'time',
#  'spend',
#  'time',
#  'spend',
#  'style',
#  'put',
#  'pon',
#  'map',
#  'deh',
#  'pon',
#  'top',
#  'name',
#  'koffee',
#  'swag',
#  'lot',
#  'dem',
#  'chat',
#  'nah',
#  'time',
#  'dem',
#  'time',
#  'dem',
#  'everything',
#  'exotic',
#  'plush',
#  'lil',
#  'baby',
#  'got',
#  'body',
#  'swear',
#  'wang',
#  'touch',
#  'pull',
#  'let',
#  'ride',
#  'girl',
#  'know',
#  'want',
#  'lust',
#  'got',
#  'excited',
#  'stop',
#  'rush',
#  'like',
#  'lunch',
#  'keep',
#  'hush',
#  'bought',
#  'benz',
#  'truck',
#  'love',
#  'see',
#  'blush',
#  'shopping',
#  'land',
#  'see',
#  'bought',
#  'prada',
#  'clutch',
#  'got',
#  'lot',
#  'bucks',
#  'cash',
#  'longer',
#  'bus',
#  'huh',
#  'warriors',
#  'warriors',
#  'looking',
#  'heart',
#  'cartier',
#  'cartier',
#  'peons',
#  'top',
#  'aria',
#  'aria',
#  'got',
#  'locked',
#  'rastafari',
#  'yeah',
#  'fari',
#  'yeah',
#  'gwan',
#  'party',
#  'yeah',
#  'party',
#  'yeah',
#  'fear',
#  'nothin',
#  'hardest',
#  'yeah',
#  'hardest',
#  'yeah',
#  'spending',
#  'cash',
#  'fun',
#  'get',
#  'pair',
#  'pair',
#  'want',
#  'gunna',
#  'wunna',
#  'cause',
#  'real',
#  'rare',
#  'real',
#  'rare',
#  'news',
#  'ina',
#  'prime',
#  'crime',
#  'dolla',
#  'sign',
#  'money',
#  'pon',
#  'mind',
#  'yeah',
#  'nah',
#  'time',
#  'spend',
#  'time',
#  'spend',
#  'style',
#  'put',
#  'pon',
#  'map',
#  'deh',
#  'pon',
#  'top',
#  'name',
#  'koffee',
#  'swag',
#  'lot',
#  'dem',
#  'chat',
#  'nah',
#  'time',
#  'dem',
#  'time',
#  'dem',
#  'pull',
#  'rocket',
#  'blast',
#  'could',
#  'never',
#  'get',
#  'half',
#  'gon',
#  'get',
#  'full',
#  'price',
#  'yeah',
#  'real',
#  'whole',
#  'life',
#  'err',
#  'twice',
#  'year',
#  'flights',
#  'moncler',
#  'cause',
#  'weather',
#  'ice',
#  'cold',
#  'really',
#  'never',
#  'check',
#  'price',
#  'living',
#  'best',
#  'life',
#  'cause',
#  'life',
#  'good',
#  'everything',
#  'give',
#  'thanks',
#  'tell',
#  'dem',
#  'wah',
#  'lowe',
#  'take',
#  'ayy',
#  'ayy',
#  'one',
#  'thing',
#  'deh',
#  'deh',
#  'ayy',
#  'ayy',
#  'nah',
#  'come',
#  'everything',
#  'give',
#  'thanks',
#  'tell',
#  'dem',
#  'wah',
#  'lowe',
#  'take',
#  'ayy',
#  'ayy',
#  'one',
#  'thing',
#  'deh',
#  'deh',
#  'ayy',
#  'ayy',
#  'nah',
#  'come',
#  'news',
#  'ina',
#  'prime',
#  'crime',
#  'dolla',
#  'sign',
#  'money',
#  'pon',
#  'mind',
#  'yeah',
#  'nah',
#  'time',
#  'spend',
#  'time',
#  'spend',
#  'style',
#  'put',
#  'pon',
#  'map',
#  'deh',
#  'pon',
#  'top',
#  'name',
#  'koffee',
#  'swag',
#  'lot',
#  'dem',
#  'chat',
#  'nah',
#  'time',
#  'dem',
#  'time',
#  'dem']

# %%
lemma = WordNetLemmatizer()

# Dictionary to convert between part-of-speech tags and the ones the lemmatizer understands

tag_dict = defaultdict(lambda : wordnet.NOUN)
tag_dict['J'] = wordnet.ADJ
tag_dict['V'] = wordnet.VERB
tag_dict['R'] = wordnet.ADV

# function to lemmatize a sentence

def get_lemma(word):
    """Gets the POS tag for a word, and then returns the lemmatized form of the word"""
    tag = pos_tag([word])[0][1][0]
    tag = tag_dict[tag]
    
    return lemma.lemmatize(word, tag)

# Perform the lemmatization
koffee_df.lyrics = koffee_df.lyrics.apply(lambda x: [get_lemma(word) for word in x])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create the list of words and their frequency (corpus)
from gensim import corpora
pyLDAvis.enable_notebook()
dictionary = corpora.Dictionary(koffee_df.lyrics )
corpus = [dictionary.doc2bow(text) for text in koffee_df.lyrics ]

import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import gensim
NUM_TOPICS = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model3.gensim')
topics = ldamodel.print_topics(num_words=6)
for topic in topics:
    print(topic)
# Out:
# (0, '0.032*"dem" + 0.027*"yuh" + 0.026*"yeah" + 0.017*"pon" + 0.017*"nuh" + 0.017*"pressure"')
# (1, '0.048*"yeah" + 0.018*"blessing" + 0.018*"toast" + 0.016*"wid" + 0.015*"say" + 0.013*"road"')
# (2, '0.039*"dem" + 0.035*"like" + 0.027*"koffee" + 0.025*"come" + 0.019*"fyah" + 0.018*"see"')
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el173291403686318655207806842175"></div>
# <script type="text/javascript">
#
# var ldavis_el173291403686318655207806842175_data = {"mdsDat": {"x": [0.07722299796985951, -0.1325260604097243, 0.055303062439864784], "y": [0.0942102360904143, 0.01099447343435207, -0.10520470952476638], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [51.52850828698776, 38.83845209254474, 9.633039620467496]}, "tinfo": {"Term": ["yeah", "wid", "fyah", "say", "pressure", "blessing", "like", "toast", "koffee", "come", "road", "rapture", "give", "haffi", "burn", "dem", "jus", "thanks", "gwaan", "life", "cyaa", "inna", "time", "friend", "right", "one", "cause", "weh", "tek", "helicopter", "pressure", "feel", "never", "pull", "cause", "pan", "spend", "style", "reach", "mmhmm", "let", "want", "hurt", "settle", "live", "enuh", "take", "fast", "start", "lot", "woy", "poor", "stress", "sometimes", "cry", "traffic", "name", "long", "everything", "chat", "well", "nah", "heart", "music", "deh", "yuh", "hear", "time", "pon", "yeah", "nuh", "inna", "haffi", "ayy", "dem", "money", "give", "tell", "ina", "know", "get", "seh", "like", "koffee", "friend", "mek", "see", "rapture", "burn", "helicopter", "lift", "capture", "doctor", "sound", "gold", "lyrical", "contractor", "fyah", "burning", "turn", "ang", "flame", "pro", "since", "around", "tame", "devil", "quench", "high", "bun", "tire", "city", "retire", "cool", "neva", "yearn", "gim", "cyaa", "place", "come", "whole", "full", "koffee", "lyric", "like", "wid", "see", "everybody", "jus", "dem", "get", "jah", "tun", "yah", "town", "seh", "yuh", "woah", "nuh", "mek", "pon", "yeah", "know", "toast", "gratitude", "siddung", "must", "thank", "oli", "earnings", "heavy", "bore", "load", "class", "plus", "fall", "blessing", "thankful", "suppose", "shower", "boast", "rise", "upon", "bus", "hand", "gwaan", "ignite", "course", "post", "fire", "third", "saw", "story", "journey", "god", "road", "thanks", "yeah", "say", "form", "life", "wid", "right", "give", "jus", "like", "weh", "pon", "tek", "see", "inna", "time", "friend", "one", "haffi"], "Freq": [63.0, 28.0, 25.0, 14.0, 27.0, 6.0, 64.0, 5.0, 48.0, 38.0, 8.0, 15.0, 20.0, 13.0, 13.0, 97.0, 10.0, 6.0, 5.0, 10.0, 15.0, 18.0, 23.0, 12.0, 7.0, 10.0, 18.0, 10.0, 10.0, 10.0, 26.73501268272868, 14.780265877802764, 8.813591202405268, 8.811592091274122, 17.34491354439168, 7.958747423802686, 7.10820936602408, 7.105383343098138, 6.256930347855872, 6.2540865418805796, 6.253816832298765, 6.254007259118892, 5.403651477596129, 5.403250618025354, 5.402405923181208, 5.402187339866275, 5.4014941714218025, 5.400819897467265, 5.399527292067605, 5.400267141016622, 5.399764028912082, 4.5505496968695, 4.550306291381516, 4.550248496471127, 4.549999163300026, 4.5499691544042475, 4.549170769584451, 4.54851316723868, 4.548938848982505, 4.548726934311079, 12.2287761858124, 12.226482172446193, 11.377585341930555, 8.811719536461133, 20.759130092569603, 42.955385463029295, 7.9628634587669245, 18.201312598852038, 27.58876799051894, 41.23524591856841, 26.739571071045514, 13.932204109646209, 10.522043578640968, 13.93367417505918, 50.66165507983746, 7.962979789548092, 13.07860143969621, 12.235934604136345, 12.234722392938956, 10.520517200238388, 13.942156689599342, 11.37906503982859, 19.082170755773156, 15.650129664462968, 8.818499324025991, 9.674301164412329, 11.384047998448663, 14.936052384793626, 13.305026346370395, 10.047207564588637, 10.046584298455102, 10.044334732159506, 5.974462728385899, 5.15918706410865, 5.159495904764426, 5.15935181635721, 5.159300435994948, 23.081399085756285, 10.04636425646889, 4.344637147448365, 4.344204602985619, 4.343742738207452, 4.344390019075525, 4.34355257501886, 4.342548703267039, 3.5304541535925003, 3.5303237479991485, 3.530270412949191, 3.530095328779958, 3.5300520464095735, 3.530026356228442, 3.529971904214088, 3.5299227577806187, 3.529819717814994, 3.5296144756070413, 3.5292076213254275, 3.529463685413444, 13.312153696187773, 10.862859645867681, 29.60451137506465, 6.788823598821988, 9.231161753359645, 32.87314237220955, 8.419630712223402, 41.82 ...

# %% [markdown]
# # Wordcloud

# %%
koffee_df.lyrics = koffee_df.lyrics.apply(lambda x: " ".join(x))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Create an object that converts strings into a sparse matrix
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features= 20000 , min_df=0.01, ngram_range= (1,1))

# Convert the text column to a sparse matrix

data_dtm = vectorizer.fit_transform(koffee_df.lyrics)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create a dataframe of terms and frequencies
# Get the frequency of each term

term_frequencies = data_dtm.sum(axis=0)

# Match frequencies to terms

frequent_terms = [(word, term_frequencies[0, id]) for word, id in vectorizer.vocabulary_.items()]

# Convert the word-frequency pairings to a dataframe

term_df = pd.DataFrame(columns=["term","frequency"], data=frequent_terms)

# Sort the dataframe

term_df.sort_values(by="frequency", ascending=False, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create a dictionary of most frequent terms ((required for word clouds)

term_dict = term_df.set_index('term')['frequency'].to_dict()

# Create a wordcloud of most frequent terms

wc = WordCloud(width=800, height=300, background_color="white",
               max_words=100)

wc.generate_from_frequencies(term_dict)

# Display the cloud

plt.figure(figsize=(20, 10))
plt.title("Word cloud for lyrics including all genres", fontsize = 40, pad = 50 )
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Sentiment

# %%
# Assign sentiment to each lyric
koffee_df["sentiment"] = koffee_df.lyrics.apply(lambda x: TextBlob(x).sentiment.polarity)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-51-94c2af134d94>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   koffee_df["sentiment"] = koffee_df.lyrics.apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
koffee_df.sort_values(by="sentiment", ascending=False).head(10)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                full_title  artist  \
# 1                 W by Koffee (Ft. Gunna)  Koffee
# 8    Blazin by Koffee (Ft. Jane Macgizmo)  Koffee
# 6  Rapture (Remix) by Koffee (Ft. Govana)  Koffee
# 2                       Rapture by Koffee  Koffee
# 0                         Toast by Koffee  Koffee
# 5                       Burning by Koffee  Koffee
# 4                   Raggamuffin by Koffee  Koffee
# 3                      Lockdown by Koffee  Koffee
# 7                        Throne by Koffee  Koffee
# 9                      Pressure by Koffee  Koffee
#
#                                               lyrics  sentiment
# 1  izy kid news ina prime crime dolla sign money ...   0.287821
# 8  put flame diesel ketch fyah mek burn say praye...   0.283605
# 6  genna genna koffee come like rapture yeh yeh l...   0.214655
# 2  koffee come like rapture koffee come like rapt...   0.172297
# 0  cyaa bawl inna life man gwaan wid gwaan wid iz...   0.170677
# 5  ooh ooh come wid fyah come wid fyah city burni...   0.161884
# 4  mmhmm frankie music frankie raggamuffin reggae...   0.126766
# 3  quarantine ting do everybody touch road mommy ...   0.100000
# 7  woah deh pon tell dem watch inna traffic koffe...  -0.030383
# 9  ooh yeah never give ooh yeah never give pressu...  -0.075902
