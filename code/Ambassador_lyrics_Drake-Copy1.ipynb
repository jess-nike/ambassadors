# %%
#Copy the code and change the name for other artists
artist_name = "Drake"

# %%
import pandas as pd
import codecs
import json
from pandas.io.json import json_normalize
import re

# %%
#Machine learning libraries for Text analysis
import nltk  # machine learning with text
from nltk import download as nltk_download
from nltk.corpus import stopwords, wordnet  # List of common words
from nltk.tokenize import word_tokenize  # Split text into significant forms
from nltk.stem import WordNetLemmatizer  # Reduce words to their root form
from nltk import pos_tag  # Tag words with parts of speech
from collections import defaultdict, Counter  # Dictionaries that have a backup value
from sklearn.feature_extraction.text import CountVectorizer  # Convert text to sparse matrices
from textblob import TextBlob  # Sentiment analysis
from gensim.models.ldamodel import LdaModel  # Topic extraction
from gensim.models.phrases import Phrases, ENGLISH_CONNECTOR_WORDS  # ngrams
from gensim.models.phrases import Phraser  # ngrams
from gensim import corpora, models, similarities  # Vectorization
import pyLDAvis
from wordcloud import WordCloud  # Create wordclouds
import matplotlib.pylab as plt

# %% [markdown]
# # Run next 2 cells only if you want to pull data from Genius

# %%
from lyricsgenius import Genius

genius = Genius('JOSfSO0Cn0Y3avlw_ItRLdmwFj3s-36fjS-POUolMGFiWkUiE_zHXfQZVsOOqbxA', timeout=10)
artist = genius.search_artist(artist_name, max_songs = 300) # use max_songs=10 parameter to limit to 10 songs

# %%
artist_json = artist.save_lyrics()

# %% [markdown]
# # Start here to use the data from the file on disk

# %%
#load the file
name_string = artist_name.replace(' ', '')
lyricsFile = "Lyrics_"+str(name_string)+".json"
with open(lyricsFile) as json_data:
    data = json.load(json_data)

# convert to dataframe
df = pd.DataFrame(data['songs'])
artist_df = df[['full_title', 'title', 'artist', 'lyrics', 'featured_artists', 'release_date']]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Lyric Analysis
#
# ## Cleaning the lyrics

# %%
# convert everything to lower case
artist_df.lyrics = artist_df.lyrics.str.lower()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
artist_df.lyrics[2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# "[intro]\nyou used to call me on my\nyou used to, you used to\nyeah\n\n[chorus]\nyou used to call me on my cell phone\nlate-night when you need my love\ncall me on my cell phone\nlate-night when you need my love\nand i know when that hotline bling\nthat can only mean one thing\ni know when that hotline bling\nthat can only mean one thing\n\n[verse 1]\never since i left the city, you\ngot a reputation for yourself now\neverybody knows and i feel left out\ngirl, you got me down, you got me stressed out\n'cause ever since i left the city, you\nstarted wearing less and goin' out more\nglasses of champagne out on the dance floor\nhangin' with some girls i've never seen before\n\n[chorus]\nyou used to call me on my cell phone\nlate-night when you need my love\ncall me on my cell phone\nlate-night when you need my love\ni know when that hotline bling\nthat can only mean one thing\ni know when that hotline bling\nthat can only mean one thing\n\n[verse 2]\never since i left the city, you, you, you\nyou and me, we just don't get along\nyou make me feel like i did you wrong\ngoing places where you don't belong\never since i left the city, you\nyou got exactly what you asked for\nrunning out of pages in your passport\nhangin' with some girls i've never seen before\n\n[chorus]\nyou used to call me on my cell phone\nlate-night when you need my love\ncall me on my cell phone\nlate-night when you need my love\nand i know when that hotline bling\nthat can only mean one thing\ni know when that hotline bling\nthat can only mean one thing\n\n[bridge]\nthese days, all i do is\nwonder if you're bendin' over backwards for someone else\nwonder if you're rolling up a backwoods for someone else\ndoing things i taught you, gettin' nasty for someone else\nyou don't need no one else\nyou don't need nobody else, no\nwhy you never alone?\nwhy you always touching road?\nused to always stay at home\nbe a good girl, you was in the zone\nyeah, you should just be yourself\nright now, you're someone else\n\n[chorus]\nyou used to call me on my cell phone\nlate-night when you need my love\ncall me on my cell phone\nlate-night when you need my love\nand i know when that hotline bling\nthat can only mean one thing\ni know when that hotline bling\nthat can only mean one thing\n\n[outro]\never since i left the city…\n\n[produced by nineteen85]"

# %%
# remove the embed, share, copy at the end of each lyric
artist_df.lyrics = artist_df.lyrics.replace(to_replace="embedshare url:copyembed:copy", value="", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Remove quotes
artist_df.lyrics = artist_df.lyrics.replace(to_replace="(\u2019)", value="'", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# convert common contractions to the full word or phrase
artist_df.lyrics = artist_df.lyrics.replace(to_replace="wont", value="will not", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="wouldn't", value="wouldnt", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="can't", value="cannot", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="don't", value="dont", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="'re", value=" are", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="wanna", value="want to", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="ain't", value="aint", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="gotta", value="got to", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="'ll", value=" will", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="lil'", value="little", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="hol'", value="hold", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="y'all", value="you all", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# convert more common contractions to the full word or phrase
artist_df.lyrics = artist_df.lyrics.replace(to_replace="it's", value="it is", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="that's", value="that is", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="i've", value="i have", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="i'm", value="i am", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="you're", value="you are", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="you've", value="you have", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="n' ", value="ng ", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="'n ", value="ing ", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="'s ", value="s ", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace=" 'em ", value="them ", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace="&", value="and", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Remove common interjections, or singing sounds
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"aah|aagh|ayy|ay|ooh|oh|huh", value="", regex=True) 
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"hmm|mmm|brr", value="", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"yeah", value="", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"woah", value="", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# remove verse, chorus, bridge, intro , outro anotations 
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"\[[^]]*\]", value="", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# get rid of tabs, new line, return symbols and parentheses
artist_df.lyrics = artist_df.lyrics.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=" ", regex=True)
artist_df.lyrics = artist_df.lyrics.replace(to_replace=[r"\(|\)", ""], value=" ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics[2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# " you used to call me on my you used to, you used to    you used to call me on my cell phone late-night when you need my love call me on my cell phone late-night when you need my love and i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   ever since i left the city, you got a reputation for yourself now everybody knows and i feel left out girl, you got me down, you got me stressed out 'cause ever since i left the city, you started wearing less and going out more glasses of champagne out on the dance floor hanging with some girls i have never seen before   you used to call me on my cell phone late-night when you need my love call me on my cell phone late-night when you need my love i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   ever since i left the city, you, you, you you and me, we just dont get along you make me feel like i did you wrong going places where you dont belong ever since i left the city, you you got exactly what you asked for running out of pages in your passport hanging with some girls i have never seen before   you used to call me on my cell phone late-night when you need my love call me on my cell phone late-night when you need my love and i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   these ds, all i do is wonder if you are bending over backwards for someone else wonder if you are rolling up a backwoods for someone else doing things i taught you, getting nasty for someone else you dont need no one else you dont need nobody else, no why you never alone? why you alws touching road? used to alws st at home be a good girl, you was in the zone , you should just be yourself right now, you are someone else   you used to call me on my cell phone late-night when you need my love call me on my cell phone late-night when you need my love and i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   ever since i left the city…  "

# %%
# remove any other symbols except letters, numbers and underscore
artist_df.lyrics = artist_df.lyrics.replace(to_replace=r"\W", value=" ", regex=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics[2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ' you used to call me on my you used to  you used to    you used to call me on my cell phone late night when you need my love call me on my cell phone late night when you need my love and i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   ever since i left the city  you got a reputation for yourself now everybody knows and i feel left out girl  you got me down  you got me stressed out  cause ever since i left the city  you started wearing less and going out more glasses of champagne out on the dance floor hanging with some girls i have never seen before   you used to call me on my cell phone late night when you need my love call me on my cell phone late night when you need my love i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   ever since i left the city  you  you  you you and me  we just dont get along you make me feel like i did you wrong going places where you dont belong ever since i left the city  you you got exactly what you asked for running out of pages in your passport hanging with some girls i have never seen before   you used to call me on my cell phone late night when you need my love call me on my cell phone late night when you need my love and i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   these ds  all i do is wonder if you are bending over backwards for someone else wonder if you are rolling up a backwoods for someone else doing things i taught you  getting nasty for someone else you dont need no one else you dont need nobody else  no why you never alone  why you alws touching road  used to alws st at home be a good girl  you was in the zone   you should just be yourself right now  you are someone else   you used to call me on my cell phone late night when you need my love call me on my cell phone late night when you need my love and i know when that hotline bling that can only mean one thing i know when that hotline bling that can only mean one thing   ever since i left the city   '

# %%
artist_df_clean = artist_df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Tokenize
artist_df.lyrics = artist_df.lyrics.apply(word_tokenize)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics[2]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['you',
#  'used',
#  'to',
#  'call',
#  'me',
#  'on',
#  'my',
#  'you',
#  'used',
#  'to',
#  'you',
#  'used',
#  'to',
#  'you',
#  'used',
#  'to',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'and',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'ever',
#  'since',
#  'i',
#  'left',
#  'the',
#  'city',
#  'you',
#  'got',
#  'a',
#  'reputation',
#  'for',
#  'yourself',
#  'now',
#  'everybody',
#  'knows',
#  'and',
#  'i',
#  'feel',
#  'left',
#  'out',
#  'girl',
#  'you',
#  'got',
#  'me',
#  'down',
#  'you',
#  'got',
#  'me',
#  'stressed',
#  'out',
#  'cause',
#  'ever',
#  'since',
#  'i',
#  'left',
#  'the',
#  'city',
#  'you',
#  'started',
#  'wearing',
#  'less',
#  'and',
#  'going',
#  'out',
#  'more',
#  'glasses',
#  'of',
#  'champagne',
#  'out',
#  'on',
#  'the',
#  'dance',
#  'floor',
#  'hanging',
#  'with',
#  'some',
#  'girls',
#  'i',
#  'have',
#  'never',
#  'seen',
#  'before',
#  'you',
#  'used',
#  'to',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'ever',
#  'since',
#  'i',
#  'left',
#  'the',
#  'city',
#  'you',
#  'you',
#  'you',
#  'you',
#  'and',
#  'me',
#  'we',
#  'just',
#  'dont',
#  'get',
#  'along',
#  'you',
#  'make',
#  'me',
#  'feel',
#  'like',
#  'i',
#  'did',
#  'you',
#  'wrong',
#  'going',
#  'places',
#  'where',
#  'you',
#  'dont',
#  'belong',
#  'ever',
#  'since',
#  'i',
#  'left',
#  'the',
#  'city',
#  'you',
#  'you',
#  'got',
#  'exactly',
#  'what',
#  'you',
#  'asked',
#  'for',
#  'running',
#  'out',
#  'of',
#  'pages',
#  'in',
#  'your',
#  'passport',
#  'hanging',
#  'with',
#  'some',
#  'girls',
#  'i',
#  'have',
#  'never',
#  'seen',
#  'before',
#  'you',
#  'used',
#  'to',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'and',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'these',
#  'ds',
#  'all',
#  'i',
#  'do',
#  'is',
#  'wonder',
#  'if',
#  'you',
#  'are',
#  'bending',
#  'over',
#  'backwards',
#  'for',
#  'someone',
#  'else',
#  'wonder',
#  'if',
#  'you',
#  'are',
#  'rolling',
#  'up',
#  'a',
#  'backwoods',
#  'for',
#  'someone',
#  'else',
#  'doing',
#  'things',
#  'i',
#  'taught',
#  'you',
#  'getting',
#  'nasty',
#  'for',
#  'someone',
#  'else',
#  'you',
#  'dont',
#  'need',
#  'no',
#  'one',
#  'else',
#  'you',
#  'dont',
#  'need',
#  'nobody',
#  'else',
#  'no',
#  'why',
#  'you',
#  'never',
#  'alone',
#  'why',
#  'you',
#  'alws',
#  'touching',
#  'road',
#  'used',
#  'to',
#  'alws',
#  'st',
#  'at',
#  'home',
#  'be',
#  'a',
#  'good',
#  'girl',
#  'you',
#  'was',
#  'in',
#  'the',
#  'zone',
#  'you',
#  'should',
#  'just',
#  'be',
#  'yourself',
#  'right',
#  'now',
#  'you',
#  'are',
#  'someone',
#  'else',
#  'you',
#  'used',
#  'to',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'call',
#  'me',
#  'on',
#  'my',
#  'cell',
#  'phone',
#  'late',
#  'night',
#  'when',
#  'you',
#  'need',
#  'my',
#  'love',
#  'and',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'i',
#  'know',
#  'when',
#  'that',
#  'hotline',
#  'bling',
#  'that',
#  'can',
#  'only',
#  'mean',
#  'one',
#  'thing',
#  'ever',
#  'since',
#  'i',
#  'left',
#  'the',
#  'city']

# %% [markdown]
# ## Analysis: common 2 and 3 word phrases found in the lyrics

# %%
# Divide the lyrics into "sentences" so that the phrases don't straddle songs.   Each song = one sentence
sentences = []
for l in artist_df.lyrics:
    sentences.append(l)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Number of sentences should equal the number of songs
len(sentences)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 300

# %%
# check our result on the first sentence
sentences[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['and',
#  'they',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishin',
#  'they',
#  'wishing',
#  'on',
#  'me',
#  'i',
#  'been',
#  'moving',
#  'calm',
#  'dont',
#  'start',
#  'no',
#  'trouble',
#  'with',
#  'me',
#  'tryna',
#  'keep',
#  'it',
#  'peaceful',
#  'is',
#  'a',
#  'struggle',
#  'for',
#  'me',
#  'dont',
#  'pull',
#  'up',
#  'at',
#  '6',
#  'am',
#  'to',
#  'cuddle',
#  'with',
#  'me',
#  'you',
#  'know',
#  'how',
#  'i',
#  'like',
#  'it',
#  'when',
#  'you',
#  'loving',
#  'on',
#  'me',
#  'i',
#  'dont',
#  'want',
#  'to',
#  'die',
#  'for',
#  'them',
#  'to',
#  'miss',
#  'me',
#  'yes',
#  'i',
#  'see',
#  'the',
#  'things',
#  'that',
#  'they',
#  'wishing',
#  'on',
#  'me',
#  'hope',
#  'i',
#  'got',
#  'some',
#  'brothers',
#  'that',
#  'outlive',
#  'me',
#  'they',
#  'gong',
#  'tell',
#  'the',
#  'story',
#  'shit',
#  'was',
#  'different',
#  'with',
#  'me',
#  'gods',
#  'plan',
#  'gods',
#  'plan',
#  'i',
#  'hold',
#  'back',
#  'sometimes',
#  'i',
#  'won',
#  't',
#  'yuh',
#  'i',
#  'feel',
#  'good',
#  'sometimes',
#  'i',
#  'dont',
#  'dont',
#  'i',
#  'finessed',
#  'down',
#  'weston',
#  'road',
#  'nessed',
#  'might',
#  'go',
#  'down',
#  'a',
#  'g',
#  'o',
#  'd',
#  'wait',
#  'i',
#  'go',
#  'hard',
#  'on',
#  'southside',
#  'g',
#  'wait',
#  'i',
#  'make',
#  'sure',
#  'that',
#  'north',
#  'side',
#  'eat',
#  'and',
#  'still',
#  'bad',
#  'things',
#  'it',
#  'is',
#  'a',
#  'lot',
#  'of',
#  'bad',
#  'things',
#  'that',
#  'they',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishin',
#  'they',
#  'wishing',
#  'on',
#  'me',
#  'bad',
#  'things',
#  'it',
#  'is',
#  'a',
#  'lot',
#  'of',
#  'bad',
#  'things',
#  'that',
#  'they',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishin',
#  'they',
#  'wishing',
#  'on',
#  'me',
#  'she',
#  's',
#  'do',
#  'you',
#  'love',
#  'me',
#  'i',
#  'tell',
#  'her',
#  'only',
#  'partly',
#  'i',
#  'only',
#  'love',
#  'my',
#  'bed',
#  'and',
#  'my',
#  'mama',
#  'i',
#  'am',
#  'sorry',
#  'fifty',
#  'dub',
#  'i',
#  'even',
#  'got',
#  'it',
#  'tatted',
#  'on',
#  'me',
#  '81',
#  'they',
#  'will',
#  'bring',
#  'the',
#  'crashers',
#  'to',
#  'the',
#  'party',
#  'and',
#  'you',
#  'know',
#  'me',
#  'turn',
#  'the',
#  'o2',
#  'into',
#  'the',
#  'o3',
#  'dog',
#  'without',
#  '40',
#  'oli',
#  'there',
#  'd',
#  'be',
#  'no',
#  'me',
#  'magine',
#  'if',
#  'i',
#  'never',
#  'met',
#  'the',
#  'broskies',
#  'gods',
#  'plan',
#  'gods',
#  'plan',
#  'i',
#  'can',
#  'not',
#  'do',
#  'this',
#  'on',
#  'my',
#  'own',
#  'no',
#  'someone',
#  'watching',
#  'this',
#  'shit',
#  'close',
#  'yep',
#  'close',
#  'i',
#  'have',
#  'been',
#  'me',
#  'since',
#  'scarlett',
#  'road',
#  'road',
#  'might',
#  'go',
#  'down',
#  'as',
#  'g',
#  'o',
#  'd',
#  'wait',
#  'i',
#  'go',
#  'hard',
#  'on',
#  'southside',
#  'g',
#  'wait',
#  'i',
#  'make',
#  'sure',
#  'that',
#  'north',
#  'side',
#  'eat',
#  'and',
#  'still',
#  'bad',
#  'things',
#  'it',
#  'is',
#  'a',
#  'lot',
#  'of',
#  'bad',
#  'things',
#  'that',
#  'they',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishin',
#  'they',
#  'wishing',
#  'on',
#  'me',
#  'bad',
#  'things',
#  'it',
#  'is',
#  'a',
#  'lot',
#  'of',
#  'bad',
#  'things',
#  'that',
#  'they',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishing',
#  'and',
#  'wishin',
#  'they',
#  'wishing',
#  'on',
#  'me']

# %%
# Look for frequently used 2 word combinations
from itertools import groupby

# Build the bigram model
bigram = Phrases(sentences)


# Find bigrams in the songs
two_word_phrases = []
i=0
while i < len(sentences): 
    bigrams = bigram[sentences[i]]
    for s in bigrams:
        if len(re.findall('_', s)) > 0:
            two_word_phrases.append(s)
    i = i + 1
two_word_phrases_df = pd.DataFrame(two_word_phrases, columns = ['Phrases'])
test = two_word_phrases_df.groupby(by = "Phrases").size().reset_index(name='counts')
test.sort_values(by = 'counts', ascending = False).head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Phrases  counts
# 65     can_not     475
# 427    want_to     410
# 401  this_shit     174
# 325  right_now     144
# 193  have_been     143

# %%
# Looking for 3 word combinations 

# Build the trigram models
trigram = Phrases(bigram[sentences])

tri = []

# Construct trigram list looking at all songs
i=0
while i < len(sentences): 
    songtrigram = trigram[bigram[sentences[i]]]
    for s in songtrigram:
        if len(re.findall('_', s)) > 1:
            tri.append(s)
    i = i + 1

tri_df = pd.DataFrame(tri, columns = ['Phrases'])
test_tri = tri_df.groupby(by = "Phrases").size().reset_index(name='counts')
test_tri.sort_values(by = 'counts', ascending = False).head(30)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       Phrases  counts
# 105               it_is_yours      80
# 3                    a_lot_of      76
# 189                want_to_be      53
# 137                on_my_mind      35
# 98              in_this_bitch      33
# 154              shout_out_to      26
# 14                ama_go_hard      24
# 147                 s_my_name      23
# 131             nigga_we_made      23
# 12               am_ready_for      23
# 126               need_no_one      22
# 34               can_not_even      22
# 39       can_not_stop_missing      22
# 171           the_whole_thing      22
# 133           no_more_no_more      21
# 1                a_little_bit      21
# 103               is_for_sure      21
# 177       this_shit_belong_to      20
# 176           they_gong_think      20
# 5              aint_no_tellin      20
# 136             nobody_else_s      20
# 211              won_a_grammy      20
# 182         too_much_too_much      19
# 186                used_to_be      19
# 104               is_too_late      18
# 71            from_the_bottom      18
# 114  like_controlla_controlla      18
# 106              just_be_mine      18
# 26     been_tryin_tryin_tryin      17
# 108           just_more_ready      17

# %%
fourgram = Phrases(trigram[sentences])
four = []

# Construct trigram list looking at all songs
i=0
while i < len(sentences): 
    songtrigram = fourgram[trigram[sentences[i]]]
    for s in songtrigram:
        if len(re.findall('_', s)) > 2:
            four.append(s)
    i = i + 1
    
four_df = pd.DataFrame(four, columns = ['Phrases'])
test_four = four_df.groupby(by = "Phrases").size().reset_index(name='counts')
test_four.sort_values(by = 'counts', ascending = False).head(20)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                         Phrases  counts
# 9          can_not_stop_missing      22
# 42          this_shit_belong_to      20
# 32              no_more_no_more      20
# 33                  no_no_no_no      19
# 43            too_much_too_much      19
# 4        been_tryin_tryin_tryin      17
# 2             bass_is_kickin_my      13
# 7          can_not_explain_this      13
# 47    wonder_whatever_became_of      12
# 30         nails_done_hair_done      12
# 45              will_be_fine_we      12
# 35  preach_preach_preach_preach      12
# 44        want_to_be_successful      12
# 16              every_d_every_d      12
# 38      started_from_the_bottom      11
# 39          tat_my_fucking_name      11
# 23                  go_go_go_go      11
# 25                  ha_ha_ha_ha      11
# 18    everything_big_nails_done      10
# 14                down_e_down_e      10

# %%
len(set(tri))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 219

# %%
from gensim.models.phrases import Phrases, Phraser

phrases = Phrases(sentences, min_count=5, threshold=10, connector_words=ENGLISH_CONNECTOR_WORDS)
phrases_df = pd.DataFrame(columns = ['phrase', 'score'])
phrase_col = []
score_col = []
wordcount_col = []
for phrase, score in phrases.find_phrases(sentences).items():
    phrase_col.append(phrase)
    score_col.append(score)
    wordcount_col.append(len(re.findall('_', phrase)) + 1)   
phrases_df['phrase'] = phrase_col
phrases_df['score'] = score_col
phrases_df['wordcount'] = wordcount_col
phrases_df[phrases_df['wordcount'] > 2].sort_values(by='wordcount', ascending = False).head(50)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                       phrase        score  wordcount
# 413        dance_to_the_song    24.955273          4
# 96      sitting_on_the_bench   222.814935          4
# 112  started_from_the_bottom   471.339286          4
# 397       heat_of_the_moment   448.868459          4
# 1        wishing_and_wishing   408.008323          3
# 373          turn_the_lights   116.712585          3
# 313           work_the_night    15.036591          3
# 319             run_and_tell    17.620763          3
# 320           about_the_team    10.770088          3
# 321           only_on_camera   129.975379          3
# 350            stop_the_ride    11.487613          3
# 366         wavethem_at_them   105.041327          3
# 388             won_a_grammy   300.556204          3
# 384            have_to_teach    12.476502          3
# 386            about_to_glow    12.459513          3
# 305            over_and_over    10.074280          3
# 396           bout_to_happen    70.562427          3
# 404             is_a_madness    15.981005          3
# 405             is_a_catfish    15.981005          3
# 408           all_the_demons    11.713091          3
# 311            sick_of_these    13.457594          3
# 293            blem_for_real    95.714086          3
# 301      redemptions_on_your    27.290695          3
# 150            lot_of_people    25.628948          3
# 44              want_to_hear    13.729394          3
# 89             rest_in_peace   478.051858          3
# 91              want_a_photo    13.573378          3
# 116           half_a_million   100.552381          3
# 118              give_a_fuck    16.495709          3
# 138             hit_the_club    20.891020          3
# 143           like_a_soldier    10.031232          3
# 198              take_a_shot    26.233563          3
# 30             taking_a_hold    10.810807          3
# 202      smoking_the_chicken  1109.123232          3
# 230            want_to_fight    22.860426          3
# 235          loving_the_crew   309.130631          3
# 237         belong_to_nobody   311.940909          3
# 249            feel_the_same    13.892909          3
# 252          just_the_motion    35.476627          3
# 256      bros_for_assistance  1906.305556          3
# 428             ready_for_ya    56.410583          3

# %%
from nltk import ngrams
tgs = nltk.ngrams(sentences[0],5)
fdist = nltk.FreqDist(tgs)
d = Counter()
ngrams_df = pd.DataFrame(columns = ['N-gram', 'Count'])
ngrams_col = []
Count_col = []
for k, v in fdist.items():
    d[k] = v
    ngrams_col.append(k)
    Count_col.append(v)
ngrams_df['N-gram'] = ngrams_col
ngrams_df['Count'] = Count_col
ngrams_df.sort_values(by='Count', ascending = False).head(10)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                     N-gram  Count
# 2    (wishing, and, wishing, and, wishing)      5
# 3        (and, wishing, and, wishing, and)      5
# 4     (wishing, and, wishing, and, wishin)      5
# 5        (and, wishing, and, wishin, they)      5
# 6    (wishing, and, wishin, they, wishing)      5
# 7         (and, wishin, they, wishing, on)      5
# 8          (wishin, they, wishing, on, me)      5
# 1       (they, wishing, and, wishing, and)      5
# 142                   (it, is, a, lot, of)      4
# 143                  (is, a, lot, of, bad)      4

# %%
artist_df.lyrics
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0      [and, they, wishing, and, wishing, and, wishin...
# 1      [trap, trapmoneybenny, this, shit, got, me, in...
# 2      [you, used, to, call, me, on, my, you, used, t...
# 3      [baby, i, like, your, style, grips, on, your, ...
# 4      [i, got, my, eyes, on, you, you, are, everythi...
#                              ...
# 295    [man, dont, live, of, a, di, hype, real, ting,...
# 296    [hey, girl, do, you, want, my, number, that, w...
# 297    [i, did, it, all, on, my, own, turned, a, chai...
# 298    [she, be, jumping, up, and, down, trynna, fit,...
# 299    [lady, you, s, i, st, in, the, house, til, fou...
# Name: lyrics, Length: 300, dtype: object

# %%
stop_words = stopwords.words("english")
artist_df.lyrics = artist_df.lyrics.apply(lambda x: [y for y in x if y not in stop_words])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
artist_df.lyrics
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0      [wishing, wishing, wishing, wishin, wishing, m...
# 1      [trap, trapmoneybenny, shit, got, feelings, go...
# 2      [used, call, used, used, used, call, cell, pho...
# 3      [baby, like, style, grips, waist, front, w, ba...
# 4      [got, eyes, everything, see, want, hot, love, ...
#                              ...
# 295    [man, dont, live, di, hype, real, ting, pull, ...
# 296    [hey, girl, want, number, w, call, every, time...
# 297    [turned, chair, throne, king, world, stunt, ha...
# 298    [jumping, trynna, fit, ass, took, half, hour, ...
# 299    [lady, st, house, til, four, dont, even, go, a...
# Name: lyrics, Length: 300, dtype: object

# %%
lemma = WordNetLemmatizer()

# Dictionary to convert between part-of-speech tags and the ones the lemmatizer understands

tag_dict = defaultdict(lambda : wordnet.NOUN)
tag_dict['J'] = wordnet.ADJ
tag_dict['V'] = wordnet.VERB
tag_dict['R'] = wordnet.ADV

# function to lemmatize a sentence

def get_lemma(word):
    """Gets the POS tag for a word, and then returns the lemmatized form of the word"""
    tag = pos_tag([word])[0][1][0]
    tag = tag_dict[tag]
    
    return lemma.lemmatize(word, tag)

# Perform the lemmatization
#artist_df.lyrics = artist_df.lyrics.apply(lambda x: [get_lemma(word) for word in x])#
artist_df.lyrics = artist_df.lyrics.apply(lambda x: [get_lemma(word) for word in x])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
remove_words = ['like', 'get', 'got', 'know', 'say']
artist_df.lyrics = artist_df.lyrics.apply(lambda x: [y for y in x if y not in remove_words])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.lyrics[0]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['wish',
#  'wish',
#  'wish',
#  'wishin',
#  'wish',
#  'move',
#  'calm',
#  'dont',
#  'start',
#  'trouble',
#  'tryna',
#  'keep',
#  'peaceful',
#  'struggle',
#  'dont',
#  'pull',
#  '6',
#  'cuddle',
#  'love',
#  'dont',
#  'want',
#  'die',
#  'miss',
#  'yes',
#  'see',
#  'thing',
#  'wish',
#  'hope',
#  'brother',
#  'outlive',
#  'gong',
#  'tell',
#  'story',
#  'shit',
#  'different',
#  'god',
#  'plan',
#  'god',
#  'plan',
#  'hold',
#  'back',
#  'sometimes',
#  'yuh',
#  'feel',
#  'good',
#  'sometimes',
#  'dont',
#  'dont',
#  'fin',
#  'weston',
#  'road',
#  'nessed',
#  'might',
#  'go',
#  'g',
#  'wait',
#  'go',
#  'hard',
#  'southside',
#  'g',
#  'wait',
#  'make',
#  'sure',
#  'north',
#  'side',
#  'eat',
#  'still',
#  'bad',
#  'thing',
#  'lot',
#  'bad',
#  'thing',
#  'wish',
#  'wish',
#  'wish',
#  'wishin',
#  'wish',
#  'bad',
#  'thing',
#  'lot',
#  'bad',
#  'thing',
#  'wish',
#  'wish',
#  'wish',
#  'wishin',
#  'wish',
#  'love',
#  'tell',
#  'partly',
#  'love',
#  'bed',
#  'mama',
#  'sorry',
#  'fifty',
#  'dub',
#  'even',
#  'tat',
#  '81',
#  'bring',
#  'crasher',
#  'party',
#  'turn',
#  'o2',
#  'o3',
#  'dog',
#  'without',
#  '40',
#  'oli',
#  'magine',
#  'never',
#  'met',
#  'broskies',
#  'god',
#  'plan',
#  'god',
#  'plan',
#  'someone',
#  'watch',
#  'shit',
#  'close',
#  'yep',
#  'close',
#  'since',
#  'scarlett',
#  'road',
#  'road',
#  'might',
#  'go',
#  'g',
#  'wait',
#  'go',
#  'hard',
#  'southside',
#  'g',
#  'wait',
#  'make',
#  'sure',
#  'north',
#  'side',
#  'eat',
#  'still',
#  'bad',
#  'thing',
#  'lot',
#  'bad',
#  'thing',
#  'wish',
#  'wish',
#  'wish',
#  'wishin',
#  'wish',
#  'bad',
#  'thing',
#  'lot',
#  'bad',
#  'thing',
#  'wish',
#  'wish',
#  'wish',
#  'wishin',
#  'wish']

# %%
# Create the list of words and their frequency (corpus)
from gensim import corpora
pyLDAvis.enable_notebook()
#dictionary = corpora.Dictionary(artist_df.lyrics )
dictionary = corpora.Dictionary(artist_df.lyrics)
corpus = [dictionary.doc2bow(text) for text in artist_df.lyrics ]

import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import gensim
NUM_TOPICS = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model3.gensim')
topics = ldamodel.print_topics(num_words=10)
for topic in topics:
    print(topic)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (0, '0.017*"dont" + 0.016*"nigga" + 0.010*"go" + 0.010*"make" + 0.010*"want" + 0.009*"shit" + 0.009*"fuck" + 0.009*"girl" + 0.008*"aint" + 0.008*"man"')
# (1, '0.018*"go" + 0.015*"love" + 0.012*"dont" + 0.010*"girl" + 0.009*"back" + 0.009*"shit" + 0.008*"want" + 0.008*"time" + 0.008*"never" + 0.007*"one"')
# (2, '0.014*"shit" + 0.014*"go" + 0.013*"nigga" + 0.011*"dont" + 0.010*"man" + 0.008*"want" + 0.007*"never" + 0.006*"need" + 0.006*"new" + 0.006*"thing"')

# %%
import pyLDAvis.gensim_models
lda_display = pyLDAvis.gensim_models.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(lda_display)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el354941403802435732165563516593"></div>
# <script type="text/javascript">
#
# var ldavis_el354941403802435732165563516593_data = {"mdsDat": {"x": [-0.025784809963415506, -0.04685677356027183, 0.07264158352368737], "y": [0.04602161774328209, -0.037906310743090275, -0.008115307000191854], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [51.91318692012575, 32.946137814676355, 15.140675265197897]}, "tinfo": {"Term": ["go", "shit", "nigga", "man", "love", "new", "hard", "never", "need", "thing", "every", "brand", "fancy", "real", "ya", "dont", "back", "boy", "controlla", "want", "feel", "die", "w", "everything", "ok", "tell", "late", "tryin", "ama", "ever", "tryin", "preach", "tellin", "cake", "brea", "bros", "ba", "successful", "rode", "frikki", "soldier", "baow", "ha", "kind", "karma", "hov", "faithful", "fivi", "enemy", "unstoppable", "basic", "assistance", "snitch", "rush", "bottom", "yah", "fade", "share", "yamaha", "argue", "dollar", "nowads", "petty", "e", "skrrt", "control", "dark", "ready", "agree", "nigga", "much", "name", "make", "dont", "round", "smoke", "fuck", "already", "aint", "look", "come", "take", "shut", "man", "want", "even", "cause", "right", "money", "one", "keep", "time", "girl", "baby", "shit", "tryna", "let", "really", "go", "see", "tell", "still", "never", "thing", "need", "w", "think", "love", "back", "fancy", "firework", "grammy", "houstatlantavegas", "rollin", "deceive", "nail", "dedicate", "exactly", "teach", "jeffery", "redemption", "motion", "wavethem", "plugg", "sacrifice", "swanging", "thin", "deeply", "although", "sink", "wop", "hair", "cinderella", "su", "confidence", "rump", "charlie", "intro", "gotcha", "dare", "momma", "ok", "slide", "love", "everything", "behavior", "wonder", "miss", "go", "guess", "back", "well", "could", "give", "foot", "do", "hey", "somethin", "motherfucker", "little", "see", "girl", "think", "home", "never", "time", "need", "right", "would", "u", "dont", "shit", "one", "want", "tell", "let", "cause", "still", "thing", "make", "take", "nigga", "fuck", "baby", "aint", "controlla", "mi", "chicken", "spinnin", "catfish", "axl", "madness", "mek", "ga", "thangs", "bo", "inna", "skeet", "kickin", "wishin", "hows", "nuh", "yuh", "shook", "slice", "0", "stroll", "brand", "schemin", "plottin", "draft", "dovey", "lovey", "omg", "wri", "fi", "gangsta", "unruly", "blem", "motto", "band", "lifestyle", "sick", "account", "bass", "stunt", "hard", "greaze", "easy", "low", "new", "shit", "slatt", "man", "go", "nigga", "every", "late", "deserve", "real", "ya", "never", "dont", "die", "thing", "want", "need", "boy", "feel", "w", "tell", "fuck", "girl", "cause", "ama", "one", "aint", "come", "take", "back", "make", "still", "time", "see"], "Freq": [931.0, 694.0, 867.0, 468.0, 576.0, 181.0, 117.0, 451.0, 399.0, 350.0, 177.0, 39.0, 60.0, 215.0, 205.0, 995.0, 439.0, 172.0, 30.0, 618.0, 305.0, 87.0, 312.0, 158.0, 125.0, 382.0, 74.0, 80.0, 121.0, 180.0, 79.56594047545036, 76.61976440369712, 28.48642533429814, 22.951638765410078, 16.450801983514197, 15.487822207478953, 14.527885434958794, 13.594226749312151, 13.578548528358382, 11.688198659238878, 15.287744726362032, 10.741649413972329, 56.43180802003948, 11.610154693220545, 15.132390111746652, 9.795659389185323, 9.795304864503953, 9.792323058701722, 23.049998261830446, 9.766289762679627, 10.628424148992998, 8.849793870089986, 8.843310077926253, 13.24483740015783, 36.26281448630318, 20.206845374270358, 61.84826986625459, 19.391170603344044, 7.902889045009088, 7.897557985626296, 39.734826630101615, 27.793177643072056, 17.395373909575728, 60.74749605379453, 21.164564257266, 19.51727587661348, 23.222731971763782, 64.98509158541414, 14.682067796833097, 566.7248554105086, 105.12153137152833, 87.94431253642041, 354.2170214743542, 604.6605494727676, 53.30770698409001, 42.31341125365796, 322.40991116828735, 70.2012638687833, 282.13999283963767, 235.44806249351578, 247.36866790838693, 271.28081743865846, 33.85499469453899, 277.16226372768085, 350.35189210530035, 157.7276255701247, 266.8522977045257, 241.7558500350763, 149.1412403 ...

# %%
dictionary
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from gensim.test.utils import datapath
from gensim.models.word2vec import Text8Corpus
from gensim.models.phrases import Phrases, Phraser

#sentences = Text8Corpus(datapath('testcorpus.txt'))
artist_df.lyrics1 = [wd for wd in artist_df.lyrics]

# Build the bigram models
bigram = gensim.models.phrases.Phrases(artist_df.lyrics1, min_count=3, threshold=10)

# Construct bigram
print(bigram[artist_df.lyrics[0]])
# Out:
# ['wish_wish', 'wish_wishin', 'wish', 'move', 'calm', 'dont', 'start', 'trouble', 'tryna', 'keep', 'peaceful', 'struggle', 'dont', 'pull', '6', 'cuddle', 'love', 'dont', 'want', 'die', 'miss', 'yes', 'see', 'thing', 'wish', 'hope', 'brother', 'outlive', 'gong', 'tell', 'story', 'shit', 'different', 'god_plan', 'god_plan', 'hold', 'back', 'sometimes', 'yuh', 'feel', 'good', 'sometimes', 'dont', 'dont', 'fin', 'weston_road', 'nessed', 'might', 'go', 'g', 'wait', 'go_hard', 'southside', 'g', 'wait', 'make_sure', 'north', 'side', 'eat', 'still', 'bad', 'thing', 'lot', 'bad', 'thing', 'wish_wish', 'wish_wishin', 'wish', 'bad', 'thing', 'lot', 'bad', 'thing', 'wish_wish', 'wish_wishin', 'wish', 'love', 'tell', 'partly', 'love', 'bed', 'mama', 'sorry', 'fifty', 'dub', 'even', 'tat', '81', 'bring', 'crasher', 'party', 'turn', 'o2', 'o3', 'dog', 'without', '40', 'oli', 'magine', 'never', 'met', 'broskies', 'god_plan', 'god_plan', 'someone_watch', 'shit', 'close', 'yep', 'close', 'since', 'scarlett', 'road_road', 'might', 'go', 'g', 'wait', 'go_hard', 'southside', 'g', 'wait', 'make_sure', 'north', 'side', 'eat', 'still', 'bad', 'thing', 'lot', 'bad', 'thing', 'wish_wish', 'wish_wishin', 'wish', 'bad', 'thing', 'lot', 'bad', 'thing', 'wish_wish', 'wish_wishin', 'wish']
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-39-00f6d1d42edf>:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   artist_df.lyrics1 = [wd for wd in artist_df.lyrics]

# %% [markdown]
# # Wordcloud

# %%
artist_df.lyrics = artist_df.lyrics.apply(lambda x: " ".join(x))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
artist_df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                           full_title  \
# 0                                God's Plan by Drake
# 1                            In My Feelings by Drake
# 2                             Hotline Bling by Drake
# 3             One Dance by Drake (Ft. Kyla & Wizkid)
# 4  Hold On, We're Going Home by Drake (Ft. Majid ...
#
#                        title artist  \
# 0                 God’s Plan  Drake
# 1             In My Feelings  Drake
# 2              Hotline Bling  Drake
# 3                  One Dance  Drake
# 4  Hold On, We’re Going Home  Drake
#
#                                               lyrics  \
# 0  wish wish wish wishin wish move calm dont star...
# 1  trap trapmoneybenny shit feeling real kiki lov...
# 2  use call use use use call cell phone late nigh...
# 3  baby style grip waist front w back w dont pl s...
# 4  eye everything see want hot love emotion endle...
#
#                                     featured_artists release_date
# 0                                                 []   2018-01-19
# 1                                                 []   2018-06-29
# 2                                                 []   2015-07-25
# 3  [{'api_path': '/artists/155256', 'header_image...   2016-04-05
# 4  [{'api_path': '/artists/64585', 'header_image_...   2013-08-07

# %%
# Create an object that converts strings into a sparse matrix
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(max_features= 20000 , min_df=0.01, ngram_range= (1,1))

# Convert the text column to a sparse matrix

data_dtm = vectorizer.fit_transform(artist_df.lyrics)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create a dataframe of terms and frequencies
# Get the frequency of each term

term_frequencies = data_dtm.sum(axis=0)

# Match frequencies to terms

frequent_terms = [(word, term_frequencies[0, id]) for word, id in vectorizer.vocabulary_.items()]

# Convert the word-frequency pairings to a dataframe

term_df = pd.DataFrame(columns=["term","frequency"], data=frequent_terms)

# Sort the dataframe

term_df.sort_values(by="frequency", ascending=False, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create a dictionary of most frequent terms ((required for word clouds)

term_dict = term_df.set_index('term')['frequency'].to_dict()

# Create a wordcloud of most frequent terms

wc = WordCloud(width=800, height=300, background_color="white",
               max_words=100)

wc.generate_from_frequencies(term_dict)

# Display the cloud

plt.figure(figsize=(20, 10))
plt.title("Word cloud for lyrics", fontsize = 40, pad = 50 )
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Sentiment

# %%
# Assign sentiment to each lyric
artist_df["sentiment"] = artist_df.lyrics.apply(lambda x: TextBlob(x).sentiment.polarity)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-45-d312c35c4e1f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artist_df["sentiment"] = artist_df.lyrics.apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
artist_df.sort_values(by="sentiment", ascending=False).head(10)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                         full_title  \
# 194        Bria's Interlude by Drake (Ft. Omarion)
# 181                        Find Your Love by Drake
# 74                                  Signs by Drake
# 260  Loving You No More by Drake (Ft. Dirty Money)
# 248        Like I’m Supposed To/Do Things by Drake
# 62                        Best I Ever Had by Drake
# 20                 Too Good by Drake (Ft. Rihanna)
# 189                   Show Me a Good Time by Drake
# 154                         Madiba Riddim by Drake
# 291             All This Love by Drake (Ft. Voyce)
#
#                               title artist  \
# 194                Bria’s Interlude  Drake
# 181                  Find Your Love  Drake
# 74                            Signs  Drake
# 260              Loving You No More  Drake
# 248  Like I’m Supposed To/Do Things  Drake
# 62                  Best I Ever Had  Drake
# 20                         Too Good  Drake
# 189             Show Me a Good Time  Drake
# 154                   Madiba Riddim  Drake
# 291                   All This Love  Drake
#
#                                                 lyrics  \
# 194  even though alone alone go want keep warm come...
# 181  option hey hey hey refuse forgotten hey hey he...
# 74   champagne breakfast yawn drink dont start morn...
# 260  hard breathe air call love aint nothing bad hu...
# 248  hand tie someone ear side tell p mind want nig...
# 62   lot girl think song confuse one baby everythin...
# 20   look dont talk dont ask ok friend alws feel ne...
# 189  end right thing one d try forget take shot let...
# 154  tell friend need distance gon na teach love go...
# 291  southern smoke another one boy v gon tell peop...
#
#                                       featured_artists release_date  sentiment
# 194  [{'api_path': '/artists/2052', 'header_image_u...   2009-02-13   0.490000
# 181                                                 []   2010-05-05   0.371104
# 74                                                  []   2017-06-22   0.363722
# 260  [{'api_path': '/artists/2467906', 'header_imag...   2010-09-21   0.353125
# 248                                                 []         None   0.341429
# 62                                                  []   2009-02-13   0.336435
# 20   [{'api_path': '/artists/89', 'header_image_url...   2016-04-29   0.335794
# 189                                                 []   2010-06-15   0.325373
# 154                                                 []   2017-03-18   0.322902
# 291  [{'api_path': '/artists/2050', 'header_image_u...   2006-02-14   0.313381

# %%
artist_df['Datetime'] = pd.to_datetime(df['release_date'], format="%Y/%m/%d")
artist_df = artist_df.sort_values(by = "Datetime")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-47-20a3b369a7a7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   artist_df['Datetime'] = pd.to_datetime(df['release_date'], format="%Y/%m/%d")

# %%
plt = artist_df.plot(x = 'release_date', y = 'sentiment', figsize=(15, 5))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
artist_df.describe()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         sentiment
# count  300.000000
# mean     0.053423
# std      0.115369
# min     -0.432987
# 25%     -0.013420
# 50%      0.046522
# 75%      0.111257
# max      0.490000
